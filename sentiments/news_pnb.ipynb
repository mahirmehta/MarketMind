# %%
import pandas as pd

# %%
df = pd.read_csv('PNB_news.csv')

# %%
df['Published At'] = pd.to_datetime(df['Published At'])

# Convert the date format
df['Published At'] = df['Published At'].dt.strftime('%Y-%m-%d')

# Save the updated DataFrame back to a CSV file
df.to_csv('updated_PNB_news.csv', index=False)

# %%
df = pd.read_csv('updated_PNB_news.csv')

# %%
df
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 1   PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 2   PNB  IREDA, PNB collaborate to enhance financing fo...
# 3   PNB  Stock market today: Aurobindo Pharma, Bandhan ...
# 4   PNB  MSCI Rejig: PNB, BHEL, NMDC, among five additi...
# ..  ...                                                ...
# 85  PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 86  PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# 87  PNB  PNB Q2 Results: Net profit jumps 327% to ₹1,75...
# 88  PNB  PNB Q2 Results Preview: Net profit likely to j...
# 89  PNB  PNB Housing Finance share price falls over 3% ...
#
#                                           Description Published At
# 0   PNB Housing Finance has introduced a time-limi...   2024-02-19
# 1   The newly launched PMLI Small Cap fund leverag...   2024-02-18
# 2   In a significant move to accelerate renewable ...   2024-02-18
# 3   Aditya Birla Fashion and Retail, Ashok Leyland...   2024-02-13
# 4   Punjab National Bank (PNB), NMDC, BHEL, Union ...   2024-02-12
# ..                                                ...          ...
# 85  Today, Punjab National Bank, Asian Paints, Can...   2023-10-25
# 86  Asian Paints, Canara Bank, Colgate Palmolive, ...   2023-10-25
# 87  PNB’s net interest income (NII) during the Jul...   2023-10-25
# 88  Punjab National Bank (PNB) is expected to repo...   2023-10-25
# 89  PNB Housing Finance share price hit its 52-wee...   2023-10-24
#
# [90 rows x 4 columns]

# %%
df = df.rename(columns={'Published At': 'Date'})

# %%
df
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 1   PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 2   PNB  IREDA, PNB collaborate to enhance financing fo...
# 3   PNB  Stock market today: Aurobindo Pharma, Bandhan ...
# 4   PNB  MSCI Rejig: PNB, BHEL, NMDC, among five additi...
# ..  ...                                                ...
# 85  PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 86  PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# 87  PNB  PNB Q2 Results: Net profit jumps 327% to ₹1,75...
# 88  PNB  PNB Q2 Results Preview: Net profit likely to j...
# 89  PNB  PNB Housing Finance share price falls over 3% ...
#
#                                           Description        Date
# 0   PNB Housing Finance has introduced a time-limi...  2024-02-19
# 1   The newly launched PMLI Small Cap fund leverag...  2024-02-18
# 2   In a significant move to accelerate renewable ...  2024-02-18
# 3   Aditya Birla Fashion and Retail, Ashok Leyland...  2024-02-13
# 4   Punjab National Bank (PNB), NMDC, BHEL, Union ...  2024-02-12
# ..                                                ...         ...
# 85  Today, Punjab National Bank, Asian Paints, Can...  2023-10-25
# 86  Asian Paints, Canara Bank, Colgate Palmolive, ...  2023-10-25
# 87  PNB’s net interest income (NII) during the Jul...  2023-10-25
# 88  Punjab National Bank (PNB) is expected to repo...  2023-10-25
# 89  PNB Housing Finance share price hit its 52-wee...  2023-10-24
#
# [90 rows x 4 columns]

# %%
# Convert the 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by 'Date'
sorted_df = df.sort_values(by='Date')

# Optionally, reset the index if needed
sorted_df.reset_index(drop=True, inplace=True)

# %%
sorted_df
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance share price falls over 3% ...
# 1   PNB  PNB Housing Finance share price falls over 3% ...
# 2   PNB  PNB Q2 Results Preview: Net profit likely to j...
# 3   PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4   PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# ..  ...                                                ...
# 85  PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 86  PNB  IREDA, PNB collaborate to enhance financing fo...
# 87  PNB  IREDA, PNB collaborate to enhance financing fo...
# 88  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 89  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
#
#                                           Description       Date
# 0   PNB Housing Finance share price hit its 52-wee... 2023-10-24
# 1   PNB Housing Finance share price hit its 52-wee... 2023-10-24
# 2   Punjab National Bank (PNB) is expected to repo... 2023-10-25
# 3   Today, Punjab National Bank, Asian Paints, Can... 2023-10-25
# 4   Asian Paints, Canara Bank, Colgate Palmolive, ... 2023-10-25
# ..                                                ...        ...
# 85  The newly launched PMLI Small Cap fund leverag... 2024-02-18
# 86  In a significant move to accelerate renewable ... 2024-02-18
# 87  In a significant move to accelerate renewable ... 2024-02-18
# 88  PNB Housing Finance has introduced a time-limi... 2024-02-19
# 89  PNB Housing Finance has introduced a time-limi... 2024-02-19
#
# [90 rows x 4 columns]

# %%
output_file_path = 'sorted_grouped_data.csv'
sorted_df.to_csv(output_file_path, index=False)

# %%
import pandas as pd

# Read the CSV file with the news data
news_file_path = 'sorted_grouped_data.csv'
df_news = pd.read_csv(news_file_path)

# Read the CSV file with the stock data
stock_file_path = 'PNB.NS.csv'
df_stock = pd.read_csv(stock_file_path)

# Convert the 'Date' columns to datetime type in both DataFrames
df_news['Date'] = pd.to_datetime(df_news['Date'])
df_stock['Date'] = pd.to_datetime(df_stock['Date'])

# Merge the two DataFrames based on the 'Date' column
merged_df = pd.merge(df_news, df_stock, on='Date', how='left')

# Display the merged DataFrame
print(merged_df)
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance share price falls over 3% ...
# 1   PNB  PNB Housing Finance share price falls over 3% ...
# 2   PNB  PNB Q2 Results Preview: Net profit likely to j...
# 3   PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4   PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# ..  ...                                                ...
# 85  PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 86  PNB  IREDA, PNB collaborate to enhance financing fo...
# 87  PNB  IREDA, PNB collaborate to enhance financing fo...
# 88  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 89  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
#
#                                           Description       Date        Open  \
# 0   PNB Housing Finance share price hit its 52-wee... 2023-10-24         NaN
# 1   PNB Housing Finance share price hit its 52-wee... 2023-10-24         NaN
# 2   Punjab National Bank (PNB) is expected to repo... 2023-10-25   70.000000
# 3   Today, Punjab National Bank, Asian Paints, Can... 2023-10-25   70.000000
# 4   Asian Paints, Canara Bank, Colgate Palmolive, ... 2023-10-25   70.000000
# ..                                                ...        ...         ...
# 85  The newly launched PMLI Small Cap fund leverag... 2024-02-18         NaN
# 86  In a significant move to accelerate renewable ... 2024-02-18         NaN
# 87  In a significant move to accelerate renewable ... 2024-02-18         NaN
# 88  PNB Housing Finance has introduced a time-limi... 2024-02-19  130.899994
# 89  PNB Housing Finance has introduced a time-limi... 2024-02-19  130.899994
#
#           High         Low       Close   Adj Close      Volume
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2    71.400002   68.550003   69.500000   69.500000  56157100.0
# 3    71.400002   68.550003   69.500000   69.500000  56157100.0
# 4    71.400002   68.550003   69.500000   69.500000  56157100.0
# ..         ...         ...         ...         ...         ...
# 85         NaN         NaN         NaN         NaN         NaN
# 86         NaN         NaN         NaN         NaN         NaN
# 87         NaN         NaN         NaN         NaN         NaN
# 88  131.300003  128.199997  128.449997  128.449997  44582022.0
# 89  131.300003  128.199997  128.449997  128.449997  44582022.0
#
# [90 rows x 10 columns]

# %%
merged_df
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance share price falls over 3% ...
# 1   PNB  PNB Housing Finance share price falls over 3% ...
# 2   PNB  PNB Q2 Results Preview: Net profit likely to j...
# 3   PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4   PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# ..  ...                                                ...
# 85  PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 86  PNB  IREDA, PNB collaborate to enhance financing fo...
# 87  PNB  IREDA, PNB collaborate to enhance financing fo...
# 88  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 89  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
#
#                                           Description       Date        Open  \
# 0   PNB Housing Finance share price hit its 52-wee... 2023-10-24         NaN
# 1   PNB Housing Finance share price hit its 52-wee... 2023-10-24         NaN
# 2   Punjab National Bank (PNB) is expected to repo... 2023-10-25   70.000000
# 3   Today, Punjab National Bank, Asian Paints, Can... 2023-10-25   70.000000
# 4   Asian Paints, Canara Bank, Colgate Palmolive, ... 2023-10-25   70.000000
# ..                                                ...        ...         ...
# 85  The newly launched PMLI Small Cap fund leverag... 2024-02-18         NaN
# 86  In a significant move to accelerate renewable ... 2024-02-18         NaN
# 87  In a significant move to accelerate renewable ... 2024-02-18         NaN
# 88  PNB Housing Finance has introduced a time-limi... 2024-02-19  130.899994
# 89  PNB Housing Finance has introduced a time-limi... 2024-02-19  130.899994
#
#           High         Low       Close   Adj Close      Volume
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2    71.400002   68.550003   69.500000   69.500000  56157100.0
# 3    71.400002   68.550003   69.500000   69.500000  56157100.0
# 4    71.400002   68.550003   69.500000   69.500000  56157100.0
# ..         ...         ...         ...         ...         ...
# 85         NaN         NaN         NaN         NaN         NaN
# 86         NaN         NaN         NaN         NaN         NaN
# 87         NaN         NaN         NaN         NaN         NaN
# 88  131.300003  128.199997  128.449997  128.449997  44582022.0
# 89  131.300003  128.199997  128.449997  128.449997  44582022.0
#
# [90 rows x 10 columns]

# %%
output_file_path = 'PNB.csv'
sorted_df.to_csv(output_file_path, index=False)

# %%
df = pd.read_csv('PNB.csv')
df
# Out:
#    Bank                                              Title  \
# 0   PNB  PNB Housing Finance share price falls over 3% ...
# 1   PNB  PNB Housing Finance share price falls over 3% ...
# 2   PNB  PNB Q2 Results Preview: Net profit likely to j...
# 3   PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4   PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# ..  ...                                                ...
# 85  PNB  PNB MetLife unveils PMLI Small Cap Fund in its...
# 86  PNB  IREDA, PNB collaborate to enhance financing fo...
# 87  PNB  IREDA, PNB collaborate to enhance financing fo...
# 88  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
# 89  PNB  PNB Housing Finance rolls out exclusive 8.30% ...
#
#                                           Description        Date
# 0   PNB Housing Finance share price hit its 52-wee...  2023-10-24
# 1   PNB Housing Finance share price hit its 52-wee...  2023-10-24
# 2   Punjab National Bank (PNB) is expected to repo...  2023-10-25
# 3   Today, Punjab National Bank, Asian Paints, Can...  2023-10-25
# 4   Asian Paints, Canara Bank, Colgate Palmolive, ...  2023-10-25
# ..                                                ...         ...
# 85  The newly launched PMLI Small Cap fund leverag...  2024-02-18
# 86  In a significant move to accelerate renewable ...  2024-02-18
# 87  In a significant move to accelerate renewable ...  2024-02-18
# 88  PNB Housing Finance has introduced a time-limi...  2024-02-19
# 89  PNB Housing Finance has introduced a time-limi...  2024-02-19
#
# [90 rows x 4 columns]

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon (do this once)
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Create a SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Apply sentiment analysis to the 'Title' and 'Description' columns
merged_df['Title_Sentiment'] = merged_df['Title'].apply(lambda x: sia.polarity_scores(x)['compound'])
merged_df['Description_Sentiment'] = merged_df['Description'].apply(lambda x: sia.polarity_scores(x)['compound'])

# Display the DataFrame with sentiment scores
print(merged_df[['Date', 'Title', 'Title_Sentiment', 'Description', 'Description_Sentiment']])
# Out:
#          Date                                              Title  \
# 0  2023-10-24  PNB Housing Finance share price falls over 3% ...
# 1  2023-10-24  PNB Housing Finance share price falls over 3% ...
# 2  2023-10-25  PNB Q2 Results Preview: Net profit likely to j...
# 3  2023-10-25  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4  2023-10-25  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
# ..        ...                                                ...
# 85 2024-02-18  PNB MetLife unveils PMLI Small Cap Fund in its...
# 86 2024-02-18  IREDA, PNB collaborate to enhance financing fo...
# 87 2024-02-18  IREDA, PNB collaborate to enhance financing fo...
# 88 2024-02-19  PNB Housing Finance rolls out exclusive 8.30% ...
# 89 2024-02-19  PNB Housing Finance rolls out exclusive 8.30% ...
#
#     Title_Sentiment                                        Description  \
# 0            0.1531  PNB Housing Finance share price hit its 52-wee...
# 1            0.1531  PNB Housing Finance share price hit its 52-wee...
# 2            0.8074  Punjab National Bank (PNB) is expected to repo...
# 3            0.0000  Today, Punjab National Bank, Asian Paints, Can...
# 4            0.7269  Asian Paints, Canara Bank, Colgate Palmolive, ...
# ..              ...                                                ...
# 85           0.0000  The newly launched PMLI Small Cap fund leverag...
# 86           0.2732  In a significant move to accelerate renewable ...
# 87           0.2732  In a significant move to accelerate renewable ...
# 88           0.5423  PNB Housing Finance has introduced a time-limi...
# 89           0.5423  PNB Housing Finance has introduced a time-limi...
#
#     Description_Sentiment
# 0                 -0.2500
# 1                 -0.2500
# 2                  0.6705
# 3                  0.7351
# 4                  0.0000
# ..                    ...
# 85                 0.3612
# 86                 0.8126
# 87                 0.8126
# 88                 0.4588
# 89                 0.4588
#
# [90 rows x 5 columns]

# %%
df.head()
# Out:
#   Bank                                              Title  \
# 0  PNB  PNB Housing Finance share price falls over 3% ...
# 1  PNB  PNB Housing Finance share price falls over 3% ...
# 2  PNB  PNB Q2 Results Preview: Net profit likely to j...
# 3  PNB  Q2 Results today: PNB, Asian Paints, ACC, othe...
# 4  PNB  Stocks to Watch: Axis Bank, TechM, TCS, IRM En...
#
#                                          Description        Date
# 0  PNB Housing Finance share price hit its 52-wee...  2023-10-24
# 1  PNB Housing Finance share price hit its 52-wee...  2023-10-24
# 2  Punjab National Bank (PNB) is expected to repo...  2023-10-25
# 3  Today, Punjab National Bank, Asian Paints, Can...  2023-10-25
# 4  Asian Paints, Canara Bank, Colgate Palmolive, ...  2023-10-25

# %%
output_file_path = 'PNB_sentiments.csv'
merged_df.to_csv(output_file_path, index=False)
